# %% [markdown]
# <a href="https://colab.research.google.com/github/mandadimuralidharreddy/1on1-questions/blob/master/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1163, done.
# remote: Counting objects: 100% (1163/1163), done.
# remote: Compressing objects: 100% (985/985), done.
# remote: Total 1163 (delta 181), reused 739 (delta 157), pack-reused 0 (from 0)
# Receiving objects: 100% (1163/1163), 33.20 MiB | 34.03 MiB/s, done.
# Resolving deltas: 100% (181/181), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  upgrading npm...
#   node           v20.19.0 | npm 11.12.1
#                  installing bun...
#                  bun installed (1.3.13)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b8811
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-04-22 10:04:07 [info     ] 🦥 Starting Unsloth Studio...
# 2026-04-22 10:04:07 [info     ]    Loading backend...
# 2026-04-22 10:04:07 [info     ]    Starting server...
# INFO:     Started server process [2648]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CUDA -- Tesla T4
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-04-22T10:04:14.869787Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-22T10:04:16.771482Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-usw1b2-ydohpsohqxct-b.us-west1-2.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-04-22T10:04:20.216542Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 334.04}
# {"timestamp": "2026-04-22T10:04:22.320791Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 14.91}
# {"timestamp": "2026-04-22T10:04:22.924402Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 303.36}
# {"timestamp": "2026-04-22T10:04:23.255477Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 40.45}
# {"timestamp": "2026-04-22T10:04:23.882230Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 17.28}
# {"timestamp": "2026-04-22T10:04:36.236776Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-04-22T10:05:10.101340Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 76.03}
# {"timestamp": "2026-04-22T10:05:10.653682Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 155.78}
# {"timestamp": "2026-04-22T10:05:11.067816Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.46}
# {"timestamp": "2026-04-22T10:05:11.345031Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.6}
# {"timestamp": "2026-04-22T10:05:11.625592Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-04-22T10:05:11.642042Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-04-22T10:05:12.086922Z", "level": "info", "event": "Top GGUF models: ['unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/MiniMax-M2.7-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/Kimi-K2.5-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/FLUX.2-klein-9B-GGUF', 'unsloth/Qwen3-0.6B-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/gemma-3-270m-it-GGUF']"}
# {"timestamp": "2026-04-22T10:05:12.087723Z", "level": "info", "event": "Top hub models: ['unsloth/Llama-3.1-8B-Instruct', 'unsloth/Mistral-Small-3.2-24B-Instruct-2506-bnb-4bit', 'unsloth/GLM-4.7-Flash', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/gemma-4-31B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Qwen3-0.6B', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Qwen3.5-4B', 'unsloth/gpt-oss-120b-BF16', 'unsloth/gemma-4-E4B-it', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/gemma-4-E2B-it', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen3-VL-4B-Instruct', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/Qwen3.5-2B', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B', 'unsloth/Qwen3.5-0.8B', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-1.7B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-0.5B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/Qwen3-1.7B', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/gemma-4-26B-A4B-it', 'unsloth/Qwen2.5-0.5B-Instruct', 'unsloth/llama-3-8b-bnb-4bit']"}
# {"timestamp": "2026-04-22T10:05:12.096701Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 457.29}
# {"timestamp": "2026-04-22T10:05:12.101817Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 8.15}
# {"timestamp": "2026-04-22T10:05:12.103629Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 7.05}
# {"timestamp": "2026-04-22T10:05:12.108534Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-04-22T10:05:12.109416Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-04-22T10:05:12.112002Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 6.7}
# {"timestamp": "2026-04-22T10:05:12.120019Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.75}
# {"timestamp": "2026-04-22T10:05:12.400005Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.61}
# {"timestamp": "2026-04-22T10:05:17.969636Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 2.42}
# {"timestamp": "2026-04-22T10:05:17.975742Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.18}
# {"timestamp": "2026-04-22T10:05:18.130779Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-04-22T10:05:18.131509Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-04-22T10:05:18.132977Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 3.15}
# {"timestamp": "2026-04-22T10:05:18.138126Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 5.24}
# {"timestamp": "2026-04-22T10:05:18.142774Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 1.08}
# {"timestamp": "2026-04-22T10:05:18.150267Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 7.5}
# {"timestamp": "2026-04-22T10:05:19.142572Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-04-22T10:05:19.436079Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.42}
# {"timestamp": "2026-04-22T10:05:32.679732Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-22T10:05:32.685175Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-22T10:05:32.691624Z", "level": "info", "event": "Model 'unsloth/gemma-4-E2B-it' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-22T10:05:53.609562Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/gemma-4-E2B-it': model_type=gemma4, architectures=['Gemma4ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-22T10:05:57.487100Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E2B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-04-22T10:05:57.572503Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E2B-it", "status_code": 200, "process_time_ms": 24894.94}
# {"timestamp": "2026-04-22T10:06:04.729217Z", "level": "info", "event": "Checking format for dataset: unsloth/LaTeX_OCR"}
# {"timestamp": "2026-04-22T10:06:04.942457Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/519 [00:00<?, ?B/s]
# {"timestamp": "2026-04-22T10:06:06.899202Z", "level": "info", "event": "Format check result: requires_mapping=False, format=simple_image_text, is_image=True"}
# {"timestamp": "2026-04-22T10:06:06.911636Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2185.79}
# {"timestamp": "2026-04-22T10:06:08.462019Z", "level": "info", "event": "Checking format for dataset: unsloth/LaTeX_OCR"}
# {"timestamp": "2026-04-22T10:06:08.546238Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# {"timestamp": "2026-04-22T10:06:09.459236Z", "level": "info", "event": "Format check result: requires_mapping=False, format=simple_image_text, is_image=True"}
# {"timestamp": "2026-04-22T10:06:09.468267Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1008.26}
# {"timestamp": "2026-04-22T10:06:09.778508Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-22T10:06:09.783503Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-22T10:06:09.784205Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-04-22T10:06:10.363847Z", "level": "warning", "event": "Could not load config for 'unsloth/gemma-4-E2B-it': The checkpoint you are trying to load has model type `gemma4` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.\n\nYou can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`"}
# {"timestamp": "2026-04-22T10:06:10.415708Z", "level": "info", "event": "Training subprocess started (pid=5409)"}
# {"timestamp": "2026-04-22T10:06:10.435384Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 660.72}
# {"timestamp": "2026-04-22T10:06:11.426870Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 400.57}
# {"timestamp": "2026-04-22T10:06:11.428988Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 402.51}
# {"timestamp": "2026-04-22T10:06:12.530674Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.45}
# {"timestamp": "2026-04-22T10:06:12.538155Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 5.55}
# {"timestamp": "2026-04-22T10:06:13.391417Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 11.32}
# {"timestamp": "2026-04-22T10:06:14.032558Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.87}
# {"timestamp": "2026-04-22T10:06:14.042999Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 6.32}
# {"timestamp": "2026-04-22T10:06:15.553824Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 8.94}
# {"timestamp": "2026-04-22T10:06:15.556338Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms":